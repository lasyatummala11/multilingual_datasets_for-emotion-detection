# %%
import pandas as pd

# Load the dataset
file_path = "/content/cleaned_hindi_dataset_final.csv"
df = pd.read_csv(file_path)

# Pull 50 random rows
random_rows = df.sample(n=50, random_state=42)

# Display the sampled rows without using ace tools
random_rows
# Out:
#                                                 Headline  \
# 8161                                                 NaN
# 15152                                                NaN
# 13834                                                NaN
# 13279                                                NaN
# 3877   वीडियो, समुद्र की गहराई में खनन का क्यों हो रह...
# 4081   उत्तरकाशी टनल: विशेषज्ञ बोले- हिमालय के नाज़ुक...
# 11287                                                NaN
# 9251                                                 NaN
# 4110   मालदीव को लेकर भारत का अहम फ़ैसला, मुइज़्ज़ू न...
# 10108                                                NaN
# 4252   भारत-पाक मुक़ाबले से पहले कोहली और रऊफ़ की मुल...
# 1453   फ्रांस चुनाव: सत्ता की दहलीज़ पर पहुंचे धुर दक...
# 13518                                                NaN
# 3087   वीडियो, अफ़ग़ानिस्तान की जीत के बाद पाकिस्तान ...
# 8653                                                 NaN
# ...

# %%
# Define the output file path
output_file_path = "/random_hindi_sample.csv"

# Save the random sample to a CSV file
random_rows.to_csv(output_file_path, index=False)

# Provide the download link
output_file_path
# Out:
# '/random_hindi_sample.csv'

# %%
# Select only the 'Headline' and 'Content' columns and drop rows with null values
filtered_sample = random_rows[['Headline', 'Content']].dropna()

# Save the filtered sample to a CSV file
filtered_output_file_path = "/filtered_random_sample_hindi.csv"
filtered_sample.to_csv(filtered_output_file_path, index=False)

# Display the filtered sample
filtered_sample
# Out:
#                                                Headline  \
# 3877  वीडियो, समुद्र की गहराई में खनन का क्यों हो रह...
# 4081  उत्तरकाशी टनल: विशेषज्ञ बोले- हिमालय के नाज़ुक...
# 4110  मालदीव को लेकर भारत का अहम फ़ैसला, मुइज़्ज़ू न...
# 4252  भारत-पाक मुक़ाबले से पहले कोहली और रऊफ़ की मुल...
# 1453  फ्रांस चुनाव: सत्ता की दहलीज़ पर पहुंचे धुर दक...
# 3087  वीडियो, अफ़ग़ानिस्तान की जीत के बाद पाकिस्तान ...
# 2704  पंजाब के खिलाड़ियों के बिना भारत का ओलंपिक सफ़...
# 1534  टी20 वर्ल्ड कप: भारत ने अफ़ग़ानिस्तान को हराया...
# 2145  वीडियो, ब्रेस्ट कैंसर से जंग जीतने वाली छवि मि...
# 3274    एशिया कप क्रिकेट 2023: जानिए कब और कहाँ हैं मैच
# 4768  कमला हैरिस का नाम किसान आंदोलन में कैसे घसीटा ...
# 4304  नसबंदी: भारतीय पुरुष क्यों इस पर बात भी नहीं क...
# 150   काकोरी ट्रेन लूट की पूरी कहानी, जिसने अंग्रेज़...
# 884   वरुण गांधी को टिकट न मिलने पर मेनका गांधी क्या...
# 2608             पैसे की सीढ़ी लगाकर कतार पार करते अमीर
# 907   रामदेव की पतंजलि के ख़िलाफ़ शिकायतों पर सरकारो...
# ...
